# %% [markdown]
# # 2026 World Cup
# Frozen vs rolling predictions and the append-only prediction log.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
import pandas as pd, json
for m in ('frozen','rolling'):
    try:
        rep = json.load(open(f'../reports/backtests/wc2026_{m}.json'))
        print(m, rep['ensemble'])
    except FileNotFoundError:
        print(m, 'not run yet')

# %%
try:
    log = pd.read_csv('../reports/predictions/world_cup_2026_predictions.csv')
    display(log.tail(10))
except FileNotFoundError:
    print('no predictions logged yet')
