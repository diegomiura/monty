# %% [markdown]
# # Model comparison
# Expanding-window chronological validation results (produced by `python backtest.py --validate`).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
import pandas as pd
from src.evaluation.backtest import summarize_validation
table = pd.read_csv('../reports/backtests/chronological_validation_2014_2025.csv')
summarize_validation(table)

# %%
import matplotlib.pyplot as plt
piv = table.pivot(index='fold', columns='model', values='log_loss')
piv.plot(figsize=(10,4), marker='o'); plt.ylabel('log loss'); plt.title('Chronological folds'); plt.show()
