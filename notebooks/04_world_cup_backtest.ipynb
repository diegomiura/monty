# %% [markdown]
# # World Cup backtests
# Frozen-mode backtests of the 2014/2018/2022 World Cups (produced by `python backtest.py --year <Y> --mode both`).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
import json
for y in (2014, 2018, 2022):
    try:
        rep = json.load(open(f'../reports/backtests/wc{y}_frozen.json'))
        print(y, 'frozen', rep['ensemble'])
    except FileNotFoundError:
        print(y, 'not run yet')

# %%
import pandas as pd
pd.read_csv('../reports/backtests/wc2022_frozen_predictions.csv').head(10)
